# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

#Unzip the data
zep_ref = zipfile.ZipFile("/content/drive/MyDrive/DataSet/Fennal_data.zip")
zep_ref.extractall()
zep_ref.close()

# %%
# Inspect the data
import os

# Walk through the directory
for dirpath, dirnames, filenames in os.walk("Fennal_data"):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 3 directories and 0 images in 'Fennal_data'.
# There are 5 directories and 0 images in 'Fennal_data/train'.
# There are 0 directories and 857 images in 'Fennal_data/train/Carum carvi'.
# There are 0 directories and 820 images in 'Fennal_data/train/Anethum graveolens'.
# There are 0 directories and 850 images in 'Fennal_data/train/Foeniculum vulgare'.
# There are 0 directories and 813 images in 'Fennal_data/train/Cyminum cuminum'.
# There are 0 directories and 833 images in 'Fennal_data/train/Mixed Image'.
# There are 5 directories and 0 images in 'Fennal_data/val'.
# There are 0 directories and 107 images in 'Fennal_data/val/Carum carvi'.
# There are 0 directories and 102 images in 'Fennal_data/val/Anethum graveolens'.
# There are 0 directories and 106 images in 'Fennal_data/val/Foeniculum vulgare'.
# There are 0 directories and 101 images in 'Fennal_data/val/Cyminum cuminum'.
# There are 0 directories and 104 images in 'Fennal_data/val/Mixed Image'.
# There are 5 directories and 0 images in 'Fennal_data/test'.
# There are 0 directories and 108 images in 'Fennal_data/test/Carum carvi'.
# There are 0 directories and 103 images in 'Fennal_data/test/Anethum graveolens'.
# There are 0 directories and 107 images in 'Fennal_data/test/Foeniculum vulgare'.
# There are 0 directories and 103 images in 'Fennal_data/test/Cyminum cuminum'.
# There are 0 directories and 105 images in 'Fennal_data/test/Mixed Image'.

# %%
# Get the class_names programmatically
import numpy as np
import pathlib

data_dir = pathlib.Path("Fennal_data/train")
class_names = np.array(sorted([item.name for item in data_dir.glob("*")])) # Created a list of class_names from the subdirectories
print(class_names)
# Out:
# ['Anethum graveolens' 'Carum carvi' 'Cyminum cuminum' 'Foeniculum vulgare'
#  'Mixed Image']

# %%
# Define directory dataset path
train_dir = "Fennal_data/train"
val_dir = "Fennal_data/val"
test_dir = "Fennal_data/test"

# %%
# Setup data inputs
import tensorflow as tf
IMG_SIZE = (300, 300)
BATCH_SIZE = 32

train_data = tf.keras.preprocessing.image_dataset_from_directory(train_dir,
                                                                 label_mode = 'categorical',
                                                                 image_size = IMG_SIZE,
                                                                 batch_size = BATCH_SIZE)

valid_data = tf.keras.preprocessing.image_dataset_from_directory(val_dir,
                                                                label_mode = 'categorical',
                                                                image_size = IMG_SIZE,
                                                                batch_size = 1,
                                                                shuffle = True)

test_data = tf.keras.preprocessing.image_dataset_from_directory(test_dir,
                                                                label_mode = 'categorical',
                                                                image_size = IMG_SIZE,
                                                                batch_size = 1,
                                                                shuffle = True)
# Out:
# Found 4173 files belonging to 5 classes.
# Found 520 files belonging to 5 classes.
# Found 526 files belonging to 5 classes.

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

# Create data augmentation stage with horizontal flipping, rotation, zoom etc
data_augmentation = keras.Sequential([
      preprocessing.RandomFlip("horizontal"),
      preprocessing.RandomRotation(0.2),
      preprocessing.RandomZoom(0.2),
      preprocessing.RandomHeight(0.2),
      preprocessing.RandomWidth(0.2),
      #preprocessing.Rescale(1/255.)
])

# %%
# View a random image and comapre it to its augmented vwersion
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import random

target_class = random.choice(train_data.class_names)
target_dir = "Fennal_data/train/" + target_class
random_image = random.choice(os.listdir(target_dir))
random_image_path = target_dir + "/" + random_image

# Read and plot in the random image
img = mpimg.imread(random_image_path)
plt.imshow(img)
plt.title(f"Origional random image from class: {target_class}")
plt.axis(False);

# Now let's plot our augmented random image
augmented_img = data_augmentation(tf.expand_dims(img,axis=0))
plt.figure()
plt.imshow(tf.squeeze(augmented_img)/255.)
plt.title(f"Augmented random image from class: {target_class}")
plt.axis(False);

# %%
# Setup the shape and base model, freezing the base model layers
input_shape = (300, 300, 3)
base_model = tf.keras.applications.EfficientNetB3(include_top=False)
base_model.trainable = False

# Create input layer
inputs = layers.Input(shape=input_shape, name = "input_layer")

# Add in the data augmentation on Sequential model as a layer
x = data_augmentation(inputs)

# Give base model the inputs (after augmentation) and don't train it.
x = base_model(x, training=False)

# Pool output features of the base model
x = layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

#x = tf.keras.layers.Flatten()(x)
#x = tf.keras.layers.Dense(128, activation="relu")(x)
#x = tf.keras.layers.Dropout(0.2)(x)
#x = tf.keras.layers.Dense(64, activation="relu")(x)

# Put the dense layer on as the output
outputs = layers.Dense(5, activation='softmax', name='output_layer')(x)

# Make a model using the inputs and outputs
model = keras.Model(inputs, outputs)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941888/43941136 [==============================] - 2s 0us/step
# 43950080/43941136 [==============================] - 2s 0us/step

# %%
# Get a summary of model we've created
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 300, 300, 3)]     0
#
#  sequential (Sequential)     (None, None, None, 3)     0
#
#  efficientnetb3 (Functional)  (None, None, None, 1536)  10783535
#
#  global_average_pooling_laye  (None, 1536)             0
#  r (GlobalAveragePooling2D)
#
#  output_layer (Dense)        (None, 5)                 7685
#
# =================================================================
# Total params: 10,791,220
# Trainable params: 7,685
# Non-trainable params: 10,783,535
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss='categorical_crossentropy',
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

# %%
# Creating a Early Stoppage Callback
early_stoppage = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=1)

# %%
# Fit the model
history = model.fit(train_data,
                    epochs=10,
                    steps_per_epoch=len(train_data),
                    validation_data=valid_data,
                    validation_steps=len(valid_data))
# Out:
# Epoch 1/10
# 131/131 [==============================] - 324s 2s/step - loss: 0.6016 - accuracy: 0.8136 - val_loss: 0.4352 - val_accuracy: 0.8731
# Epoch 2/10
# 131/131 [==============================] - 306s 2s/step - loss: 0.2682 - accuracy: 0.9317 - val_loss: 0.3478 - val_accuracy: 0.9115
# Epoch 3/10
# 131/131 [==============================] - 301s 2s/step - loss: 0.1972 - accuracy: 0.9506 - val_loss: 0.3104 - val_accuracy: 0.9115
# Epoch 4/10
# 131/131 [==============================] - 304s 2s/step - loss: 0.1591 - accuracy: 0.9617 - val_loss: 0.2768 - val_accuracy: 0.9173
# Epoch 5/10
# 131/131 [==============================] - 295s 2s/step - loss: 0.1437 - accuracy: 0.9612 - val_loss: 0.2932 - val_accuracy: 0.9212
# Epoch 6/10
# 131/131 [==============================] - 294s 2s/step - loss: 0.1210 - accuracy: 0.9672 - val_loss: 0.2719 - val_accuracy: 0.9135
# Epoch 7/10
# 131/131 [==============================] - 298s 2s/step - loss: 0.1133 - accuracy: 0.9700 - val_loss: 0.2586 - val_accuracy: 0.9192
# Epoch 8/10
# 131/131 [==============================] - 290s 2s/step - loss: 0.1115 - accuracy: 0.9688 - val_loss: 0.2393 - val_accuracy: 0.9250
# Epoch 9/10
# 131/131 [==============================] - 288s 2s/step - loss: 0.0891 - accuracy: 0.9772 - val_loss: 0.2245 - val_accuracy: 0.9212
# Epoch 10/10
# 131/131 [==============================] - 291s 2s/step - loss: 0.0963 - accuracy: 0.9715 - val_loss: 0.2357 - val_accuracy: 0.9212

# %%
test_loss,test_acc = model.evaluate(test_data,verbose=1)
print("\n\ntest accuarcy: ",test_acc)
# Out:
# 526/526 [==============================] - 37s 71ms/step - loss: 0.2108 - accuracy: 0.9202
#
#
# test accuarcy:  0.9201520681381226

# %%
# Let's create a function to plot our loss curves...
import matplotlib.pyplot as plt

# Plot the validation and training curves
def plot_loss_curves(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label="training_loss", c='r', marker='o', linestyle='dashed')
  plt.plot(epochs, val_loss, label='val_loss',  c='b', marker='*', linestyle='dashed')
  plt.title("Loss")
  plt.xlabel("Epochs")
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label="training_accuracy",c='g', marker='o', linestyle='dashed')
  plt.plot(epochs, val_accuracy, label='val_accuracy', c='r', marker='*', linestyle='dashed')
  plt.title("Accuracy")
  plt.xlabel("Epochs")
  plt.legend()

# %%
# Check out our model's training curves
plot_loss_curves(history)

# %% [markdown]
# ### Preparing our model's layers for fine tunning

# %%
# Load an evaluate saved model
loaded_model = tf.keras.models.load_model("/content/eficientnetb3_cumin_model.h5")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-22-b7034b7111e4> in <module>()
#       1 # Load an evaluate saved model
# ----> 2 loaded_model = tf.keras.models.load_model("/content/eficientnetb3_cumin_model.h5")
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     207         if isinstance(filepath, str):
#     208           if not tf.io.gfile.exists(filepath):
# --> 209             raise IOError(f'No file or directory found at {filepath}')
#     210           if saving_utils.is_hdf5_filepath(filepath) and h5py is None:
#     211             raise ImportError(
#
# OSError: No file or directory found at /content/eficientnetb3_cumin_model.h5

# %%
loaded_model_results = loaded_model.evaluate(test_data)
loaded_model_results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f25578441ff8> in <module>()
# ----> 1 loaded_model_results = loaded_model.evaluate(test_data)
#       2 loaded_model_results
#
# NameError: name 'loaded_model' is not defined

# %%
# Layers in loaded model
model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7f0f3014f890>,
#  <keras.engine.sequential.Sequential at 0x7f0f355e3c90>,
#  <keras.engine.functional.Functional at 0x7f0f30100310>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f0f3014f350>,
#  <keras.layers.core.dense.Dense at 0x7f0f352ee2d0>]

# %%
# Are these layers trainable?
for layer in model.layers:
  print(layers, layer.trainable)
# Out:
# <module 'keras.api._v2.keras.layers' from '/usr/local/lib/python3.7/dist-packages/keras/api/_v2/keras/layers/__init__.py'> True
# <module 'keras.api._v2.keras.layers' from '/usr/local/lib/python3.7/dist-packages/keras/api/_v2/keras/layers/__init__.py'> True
# <module 'keras.api._v2.keras.layers' from '/usr/local/lib/python3.7/dist-packages/keras/api/_v2/keras/layers/__init__.py'> False
# <module 'keras.api._v2.keras.layers' from '/usr/local/lib/python3.7/dist-packages/keras/api/_v2/keras/layers/__init__.py'> True
# <module 'keras.api._v2.keras.layers' from '/usr/local/lib/python3.7/dist-packages/keras/api/_v2/keras/layers/__init__.py'> True

# %%
# What layers are in our base_model (EfficientNetB3) and are they trainable?
for i, layer in enumerate(model.layers[2].layers):
  print(i, layer.name, layer.trainable)
# Out:
# 0 input_1 False
# 1 rescaling False
# 2 normalization False
# 3 stem_conv_pad False
# 4 stem_conv False
# 5 stem_bn False
# 6 stem_activation False
# 7 block1a_dwconv False
# 8 block1a_bn False
# 9 block1a_activation False
# 10 block1a_se_squeeze False
# 11 block1a_se_reshape False
# 12 block1a_se_reduce False
# 13 block1a_se_expand False
# 14 block1a_se_excite False
# 15 block1a_project_conv False
# 16 block1a_project_bn False
# 17 block1b_dwconv False
# 18 block1b_bn False
# 19 block1b_activation False
# 20 block1b_se_squeeze False
# 21 block1b_se_reshape False
# 22 block1b_se_reduce False
# 23 block1b_se_expand False
# 24 block1b_se_excite False
# 25 block1b_project_conv False
# 26 block1b_project_bn False
# 27 block1b_drop False
# 28 block1b_add False
# 29 block2a_expand_conv False
# 30 block2a_expand_bn False
# 31 block2a_expand_activation False
# 32 block2a_dwconv_pad False
# 33 block2a_dwconv False
# 34 block2a_bn False
# 35 block2a_activation False
# 36 block2a_se_squeeze False
# 37 block2a_se_reshape False
# 38 block2a_se_reduce False
# 39 block2a_se_expand False
# 40 block2a_se_excite False
# 41 block2a_project_conv False
# 42 block2a_project_bn False
# 43 block2b_expand_conv False
# 44 block2b_expand_bn False
# 45 block2b_expand_activation False
# 46 block2b_dwconv False
# 47 block2b_bn False
# 48 block2b_activation False
# 49 block2b_se_squeeze False
# 50 block2b_se_reshape False
# 51 block2b_se_reduce False
# 52 block2b_se_expand False
# 53 block2b_se_excite False
# 54 block2b_project_conv False
# 55 block2b_project_bn False
# 56 block2b_drop False
# 57 block2b_add False
# 58 block2c_expand_conv False
# 59 block2c_expand_bn False
# 60 block2c_expand_activation False
# 61 block2c_dwconv False
# 62 block2c_bn False
# 63 block2c_activation False
# 64 block2c_se_squeeze False
# 65 block2c_se_reshape False
# 66 block2c_se_reduce False
# 67 block2c_se_expand False
# 68 block2c_se_excite False
# 69 block2c_project_conv False
# 70 block2c_project_bn False
# 71 block2c_drop False
# 72 block2c_add False
# 73 block3a_expand_conv False
# 74 block3a_expand_bn False
# 75 block3a_expand_activation False
# 76 block3a_dwconv_pad False
# 77 block3a_dwconv False
# 78 block3a_bn False
# 79 block3a_activation False
# 80 block3a_se_squeeze False
# 81 block3a_se_reshape False
# 82 block3a_se_reduce False
# 83 block3a_se_expand False
# 84 block3a_se_excite False
# 85 block3a_project_conv False
# 86 block3a_project_bn False
# 87 block3b_expand_conv False
# 88 block3b_expand_bn False
# 89 block3b_expand_activation False
# 90 block3b_dwconv False
# 91 block3b_bn False
# 92 block3b_activation False
# 93 block3b_se_squeeze False
# 94 block3b_se_reshape False
# 95 block3b_se_reduce False
# 96 block3b_se_expand False
# 97 block3b_se_excite False
# 98 block3b_project_conv False
# 99 block3b_project_bn False
# 100 block3b_drop False
# 101 block3b_add False
# 102 block3c_expand_conv False
# 103 block3c_expand_bn False
# 104 block3c_expand_activation False
# 105 block3c_dwconv False
# 106 block3c_bn False
# 107 block3c_activation False
# 108 block3c_se_squeeze False
# 109 block3c_se_reshape False
# 110 block3c_se_reduce False
# 111 block3c_se_expand False
# 112 block3c_se_excite False
# 113 block3c_project_conv False
# 114 block3c_project_bn False
# 115 block3c_drop False
# 116 block3c_add False
# 117 block4a_expand_conv False
# 118 block4a_expand_bn False
# 119 block4a_expand_activation False
# 120 block4a_dwconv_pad False
# 121 block4a_dwconv False
# 122 block4a_bn False
# 123 block4a_activation False
# 124 block4a_se_squeeze False
# 125 block4a_se_reshape False
# 126 block4a_se_reduce False
# 127 block4a_se_expand False
# 128 block4a_se_excite False
# 129 block4a_project_conv False
# 130 block4a_project_bn False
# 131 block4b_expand_conv False
# 132 block4b_expand_bn False
# 133 block4b_expand_activation False
# 134 block4b_dwconv False
# 135 block4b_bn False
# 136 block4b_activation False
# 137 block4b_se_squeeze False
# 138 block4b_se_reshape False
# 139 block4b_se_reduce False
# 140 block4b_se_expand False
# 141 block4b_se_excite False
# 142 block4b_project_conv False
# 143 block4b_project_bn False
# 144 block4b_drop False
# 145 block4b_add False
# 146 block4c_expand_conv False
# 147 block4c_expand_bn False
# 148 block4c_expand_activation False
# 149 block4c_dwconv False
# 150 block4c_bn False
# 151 block4c_activation False
# 152 block4c_se_squeeze False
# 153 block4c_se_reshape False
# 154 block4c_se_reduce False
# 155 block4c_se_expand False
# 156 block4c_se_excite False
# 157 block4c_project_conv False
# 158 block4c_project_bn False
# 159 block4c_drop False
# 160 block4c_add False
# 161 block4d_expand_conv False
# 162 block4d_expand_bn False
# 163 block4d_expand_activation False
# 164 block4d_dwconv False
# 165 block4d_bn False
# 166 block4d_activation False
# 167 block4d_se_squeeze False
# 168 block4d_se_reshape False
# 169 block4d_se_reduce False
# 170 block4d_se_expand False
# 171 block4d_se_excite False
# 172 block4d_project_conv False
# 173 block4d_project_bn False
# 174 block4d_drop False
# 175 block4d_add False
# 176 block4e_expand_conv False
# 177 block4e_expand_bn False
# 178 block4e_expand_activation False
# 179 block4e_dwconv False
# 180 block4e_bn False
# 181 block4e_activation False
# 182 block4e_se_squeeze False
# 183 block4e_se_reshape False
# 184 block4e_se_reduce False
# 185 block4e_se_expand False
# 186 block4e_se_excite False
# 187 block4e_project_conv False
# 188 block4e_project_bn False
# 189 block4e_drop False
# 190 block4e_add False
# 191 block5a_expand_conv False
# 192 block5a_expand_bn False
# 193 block5a_expand_activation False
# 194 block5a_dwconv False
# 195 block5a_bn False
# 196 block5a_activation False
# 197 block5a_se_squeeze False
# 198 block5a_se_reshape False
# 199 block5a_se_reduce False
# 200 block5a_se_expand False
# 201 block5a_se_excite False
# 202 block5a_project_conv False
# 203 block5a_project_bn False
# 204 block5b_expand_conv False
# 205 block5b_expand_bn False
# 206 block5b_expand_activation False
# 207 block5b_dwconv False
# 208 block5b_bn False
# 209 block5b_activation False
# 210 block5b_se_squeeze False
# 211 block5b_se_reshape False
# 212 block5b_se_reduce False
# 213 block5b_se_expand False
# 214 block5b_se_excite False
# 215 block5b_project_conv False
# 216 block5b_project_bn False
# 217 block5b_drop False
# 218 block5b_add False
# 219 block5c_expand_conv False
# 220 block5c_expand_bn False
# 221 block5c_expand_activation False
# 222 block5c_dwconv False
# 223 block5c_bn False
# 224 block5c_activation False
# 225 block5c_se_squeeze False
# 226 block5c_se_reshape False
# 227 block5c_se_reduce False
# 228 block5c_se_expand False
# 229 block5c_se_excite False
# 230 block5c_project_conv False
# 231 block5c_project_bn False
# 232 block5c_drop False
# 233 block5c_add False
# 234 block5d_expand_conv False
# 235 block5d_expand_bn False
# 236 block5d_expand_activation False
# 237 block5d_dwconv False
# 238 block5d_bn False
# 239 block5d_activation False
# 240 block5d_se_squeeze False
# 241 block5d_se_reshape False
# 242 block5d_se_reduce False
# 243 block5d_se_expand False
# 244 block5d_se_excite False
# 245 block5d_project_conv False
# 246 block5d_project_bn False
# 247 block5d_drop False
# 248 block5d_add False
# 249 block5e_expand_conv False
# 250 block5e_expand_bn False
# 251 block5e_expand_activation False
# 252 block5e_dwconv False
# 253 block5e_bn False
# 254 block5e_activation False
# 255 block5e_se_squeeze False
# 256 block5e_se_reshape False
# 257 block5e_se_reduce False
# 258 block5e_se_expand False
# 259 block5e_se_excite False
# 260 block5e_project_conv False
# 261 block5e_project_bn False
# 262 block5e_drop False
# 263 block5e_add False
# 264 block6a_expand_conv False
# 265 block6a_expand_bn False
# 266 block6a_expand_activation False
# 267 block6a_dwconv_pad False
# 268 block6a_dwconv False
# 269 block6a_bn False
# 270 block6a_activation False
# 271 block6a_se_squeeze False
# 272 block6a_se_reshape False
# 273 block6a_se_reduce False
# 274 block6a_se_expand False
# 275 block6a_se_excite False
# 276 block6a_project_conv False
# 277 block6a_project_bn False
# 278 block6b_expand_conv False
# 279 block6b_expand_bn False
# 280 block6b_expand_activation False
# 281 block6b_dwconv False
# 282 block6b_bn False
# 283 block6b_activation False
# 284 block6b_se_squeeze False
# 285 block6b_se_reshape False
# 286 block6b_se_reduce False
# 287 block6b_se_expand False
# 288 block6b_se_excite False
# 289 block6b_project_conv False
# 290 block6b_project_bn False
# 291 block6b_drop False
# 292 block6b_add False
# 293 block6c_expand_conv False
# 294 block6c_expand_bn False
# 295 block6c_expand_activation False
# 296 block6c_dwconv False
# 297 block6c_bn False
# 298 block6c_activation False
# 299 block6c_se_squeeze False
# 300 block6c_se_reshape False
# 301 block6c_se_reduce False
# 302 block6c_se_expand False
# 303 block6c_se_excite False
# 304 block6c_project_conv False
# 305 block6c_project_bn False
# 306 block6c_drop False
# 307 block6c_add False
# 308 block6d_expand_conv False
# 309 block6d_expand_bn False
# 310 block6d_expand_activation False
# 311 block6d_dwconv False
# 312 block6d_bn False
# 313 block6d_activation False
# 314 block6d_se_squeeze False
# 315 block6d_se_reshape False
# 316 block6d_se_reduce False
# 317 block6d_se_expand False
# 318 block6d_se_excite False
# 319 block6d_project_conv False
# 320 block6d_project_bn False
# 321 block6d_drop False
# 322 block6d_add False
# 323 block6e_expand_conv False
# 324 block6e_expand_bn False
# 325 block6e_expand_activation False
# 326 block6e_dwconv False
# 327 block6e_bn False
# 328 block6e_activation False
# 329 block6e_se_squeeze False
# 330 block6e_se_reshape False
# 331 block6e_se_reduce False
# 332 block6e_se_expand False
# 333 block6e_se_excite False
# 334 block6e_project_conv False
# 335 block6e_project_bn False
# 336 block6e_drop False
# 337 block6e_add False
# 338 block6f_expand_conv False
# 339 block6f_expand_bn False
# 340 block6f_expand_activation False
# 341 block6f_dwconv False
# 342 block6f_bn False
# 343 block6f_activation False
# 344 block6f_se_squeeze False
# 345 block6f_se_reshape False
# 346 block6f_se_reduce False
# 347 block6f_se_expand False
# 348 block6f_se_excite False
# 349 block6f_project_conv False
# 350 block6f_project_bn False
# 351 block6f_drop False
# 352 block6f_add False
# 353 block7a_expand_conv False
# 354 block7a_expand_bn False
# 355 block7a_expand_activation False
# 356 block7a_dwconv False
# 357 block7a_bn False
# 358 block7a_activation False
# 359 block7a_se_squeeze False
# 360 block7a_se_reshape False
# 361 block7a_se_reduce False
# 362 block7a_se_expand False
# 363 block7a_se_excite False
# 364 block7a_project_conv False
# 365 block7a_project_bn False
# 366 block7b_expand_conv False
# 367 block7b_expand_bn False
# 368 block7b_expand_activation False
# 369 block7b_dwconv False
# 370 block7b_bn False
# 371 block7b_activation False
# 372 block7b_se_squeeze False
# 373 block7b_se_reshape False
# 374 block7b_se_reduce False
# 375 block7b_se_expand False
# 376 block7b_se_excite False
# 377 block7b_project_conv False
# 378 block7b_project_bn False
# 379 block7b_drop False
# 380 block7b_add False
# 381 top_conv False
# 382 top_bn False
# 383 top_activation False

# %%
# How many trainable varialbes are in our base model?
print(len(model.layers[2].trainable_variables))
# Out:
# 0

# %%
# To begin fine-tuning, let's start by setting the last 10 layers of our base_model.trainable = True
base_model.trainable = True

# Freeze all layers except for the last 10 layers
for layers in base_model.layers[:-14]:
  layers.trainable = False

# Recompile (we have to recompile our models every time we make a change)
model.compile(loss='categorical_crossentropy',
               optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), # when fine-tuning you typically want to lower the learning rate by 10x*
               metrics=['accuracy'])

# %%
# Check which layers are tunable (trainable)
for layer_number, layer in enumerate(model.layers[2].layers):
  print(layer_number, layer.name, layer.trainable)
# Out:
# 0 input_1 False
# 1 rescaling False
# 2 normalization False
# 3 stem_conv_pad False
# 4 stem_conv False
# 5 stem_bn False
# 6 stem_activation False
# 7 block1a_dwconv False
# 8 block1a_bn False
# 9 block1a_activation False
# 10 block1a_se_squeeze False
# 11 block1a_se_reshape False
# 12 block1a_se_reduce False
# 13 block1a_se_expand False
# 14 block1a_se_excite False
# 15 block1a_project_conv False
# 16 block1a_project_bn False
# 17 block1b_dwconv False
# 18 block1b_bn False
# 19 block1b_activation False
# 20 block1b_se_squeeze False
# 21 block1b_se_reshape False
# 22 block1b_se_reduce False
# 23 block1b_se_expand False
# 24 block1b_se_excite False
# 25 block1b_project_conv False
# 26 block1b_project_bn False
# 27 block1b_drop False
# 28 block1b_add False
# 29 block2a_expand_conv False
# 30 block2a_expand_bn False
# 31 block2a_expand_activation False
# 32 block2a_dwconv_pad False
# 33 block2a_dwconv False
# 34 block2a_bn False
# 35 block2a_activation False
# 36 block2a_se_squeeze False
# 37 block2a_se_reshape False
# 38 block2a_se_reduce False
# 39 block2a_se_expand False
# 40 block2a_se_excite False
# 41 block2a_project_conv False
# 42 block2a_project_bn False
# 43 block2b_expand_conv False
# 44 block2b_expand_bn False
# 45 block2b_expand_activation False
# 46 block2b_dwconv False
# 47 block2b_bn False
# 48 block2b_activation False
# 49 block2b_se_squeeze False
# 50 block2b_se_reshape False
# 51 block2b_se_reduce False
# 52 block2b_se_expand False
# 53 block2b_se_excite False
# 54 block2b_project_conv False
# 55 block2b_project_bn False
# 56 block2b_drop False
# 57 block2b_add False
# 58 block2c_expand_conv False
# 59 block2c_expand_bn False
# 60 block2c_expand_activation False
# 61 block2c_dwconv False
# 62 block2c_bn False
# 63 block2c_activation False
# 64 block2c_se_squeeze False
# 65 block2c_se_reshape False
# 66 block2c_se_reduce False
# 67 block2c_se_expand False
# 68 block2c_se_excite False
# 69 block2c_project_conv False
# 70 block2c_project_bn False
# 71 block2c_drop False
# 72 block2c_add False
# 73 block3a_expand_conv False
# 74 block3a_expand_bn False
# 75 block3a_expand_activation False
# 76 block3a_dwconv_pad False
# 77 block3a_dwconv False
# 78 block3a_bn False
# 79 block3a_activation False
# 80 block3a_se_squeeze False
# 81 block3a_se_reshape False
# 82 block3a_se_reduce False
# 83 block3a_se_expand False
# 84 block3a_se_excite False
# 85 block3a_project_conv False
# 86 block3a_project_bn False
# 87 block3b_expand_conv False
# 88 block3b_expand_bn False
# 89 block3b_expand_activation False
# 90 block3b_dwconv False
# 91 block3b_bn False
# 92 block3b_activation False
# 93 block3b_se_squeeze False
# 94 block3b_se_reshape False
# 95 block3b_se_reduce False
# 96 block3b_se_expand False
# 97 block3b_se_excite False
# 98 block3b_project_conv False
# 99 block3b_project_bn False
# 100 block3b_drop False
# 101 block3b_add False
# 102 block3c_expand_conv False
# 103 block3c_expand_bn False
# 104 block3c_expand_activation False
# 105 block3c_dwconv False
# 106 block3c_bn False
# 107 block3c_activation False
# 108 block3c_se_squeeze False
# 109 block3c_se_reshape False
# 110 block3c_se_reduce False
# 111 block3c_se_expand False
# 112 block3c_se_excite False
# 113 block3c_project_conv False
# 114 block3c_project_bn False
# 115 block3c_drop False
# 116 block3c_add False
# 117 block4a_expand_conv False
# 118 block4a_expand_bn False
# 119 block4a_expand_activation False
# 120 block4a_dwconv_pad False
# 121 block4a_dwconv False
# 122 block4a_bn False
# 123 block4a_activation False
# 124 block4a_se_squeeze False
# 125 block4a_se_reshape False
# 126 block4a_se_reduce False
# 127 block4a_se_expand False
# 128 block4a_se_excite False
# 129 block4a_project_conv False
# 130 block4a_project_bn False
# 131 block4b_expand_conv False
# 132 block4b_expand_bn False
# 133 block4b_expand_activation False
# 134 block4b_dwconv False
# 135 block4b_bn False
# 136 block4b_activation False
# 137 block4b_se_squeeze False
# 138 block4b_se_reshape False
# 139 block4b_se_reduce False
# 140 block4b_se_expand False
# 141 block4b_se_excite False
# 142 block4b_project_conv False
# 143 block4b_project_bn False
# 144 block4b_drop False
# 145 block4b_add False
# 146 block4c_expand_conv False
# 147 block4c_expand_bn False
# 148 block4c_expand_activation False
# 149 block4c_dwconv False
# 150 block4c_bn False
# 151 block4c_activation False
# 152 block4c_se_squeeze False
# 153 block4c_se_reshape False
# 154 block4c_se_reduce False
# 155 block4c_se_expand False
# 156 block4c_se_excite False
# 157 block4c_project_conv False
# 158 block4c_project_bn False
# 159 block4c_drop False
# 160 block4c_add False
# 161 block4d_expand_conv False
# 162 block4d_expand_bn False
# 163 block4d_expand_activation False
# 164 block4d_dwconv False
# 165 block4d_bn False
# 166 block4d_activation False
# 167 block4d_se_squeeze False
# 168 block4d_se_reshape False
# 169 block4d_se_reduce False
# 170 block4d_se_expand False
# 171 block4d_se_excite False
# 172 block4d_project_conv False
# 173 block4d_project_bn False
# 174 block4d_drop False
# 175 block4d_add False
# 176 block4e_expand_conv False
# 177 block4e_expand_bn False
# 178 block4e_expand_activation False
# 179 block4e_dwconv False
# 180 block4e_bn False
# 181 block4e_activation False
# 182 block4e_se_squeeze False
# 183 block4e_se_reshape False
# 184 block4e_se_reduce False
# 185 block4e_se_expand False
# 186 block4e_se_excite False
# 187 block4e_project_conv False
# 188 block4e_project_bn False
# 189 block4e_drop False
# 190 block4e_add False
# 191 block5a_expand_conv False
# 192 block5a_expand_bn False
# 193 block5a_expand_activation False
# 194 block5a_dwconv False
# 195 block5a_bn False
# 196 block5a_activation False
# 197 block5a_se_squeeze False
# 198 block5a_se_reshape False
# 199 block5a_se_reduce False
# 200 block5a_se_expand False
# 201 block5a_se_excite False
# 202 block5a_project_conv False
# 203 block5a_project_bn False
# 204 block5b_expand_conv False
# 205 block5b_expand_bn False
# 206 block5b_expand_activation False
# 207 block5b_dwconv False
# 208 block5b_bn False
# 209 block5b_activation False
# 210 block5b_se_squeeze False
# 211 block5b_se_reshape False
# 212 block5b_se_reduce False
# 213 block5b_se_expand False
# 214 block5b_se_excite False
# 215 block5b_project_conv False
# 216 block5b_project_bn False
# 217 block5b_drop False
# 218 block5b_add False
# 219 block5c_expand_conv False
# 220 block5c_expand_bn False
# 221 block5c_expand_activation False
# 222 block5c_dwconv False
# 223 block5c_bn False
# 224 block5c_activation False
# 225 block5c_se_squeeze False
# 226 block5c_se_reshape False
# 227 block5c_se_reduce False
# 228 block5c_se_expand False
# 229 block5c_se_excite False
# 230 block5c_project_conv False
# 231 block5c_project_bn False
# 232 block5c_drop False
# 233 block5c_add False
# 234 block5d_expand_conv False
# 235 block5d_expand_bn False
# 236 block5d_expand_activation False
# 237 block5d_dwconv False
# 238 block5d_bn False
# 239 block5d_activation False
# 240 block5d_se_squeeze False
# 241 block5d_se_reshape False
# 242 block5d_se_reduce False
# 243 block5d_se_expand False
# 244 block5d_se_excite False
# 245 block5d_project_conv False
# 246 block5d_project_bn False
# 247 block5d_drop False
# 248 block5d_add False
# 249 block5e_expand_conv False
# 250 block5e_expand_bn False
# 251 block5e_expand_activation False
# 252 block5e_dwconv False
# 253 block5e_bn False
# 254 block5e_activation False
# 255 block5e_se_squeeze False
# 256 block5e_se_reshape False
# 257 block5e_se_reduce False
# 258 block5e_se_expand False
# 259 block5e_se_excite False
# 260 block5e_project_conv False
# 261 block5e_project_bn False
# 262 block5e_drop False
# 263 block5e_add False
# 264 block6a_expand_conv False
# 265 block6a_expand_bn False
# 266 block6a_expand_activation False
# 267 block6a_dwconv_pad False
# 268 block6a_dwconv False
# 269 block6a_bn False
# 270 block6a_activation False
# 271 block6a_se_squeeze False
# 272 block6a_se_reshape False
# 273 block6a_se_reduce False
# 274 block6a_se_expand False
# 275 block6a_se_excite False
# 276 block6a_project_conv False
# 277 block6a_project_bn False
# 278 block6b_expand_conv False
# 279 block6b_expand_bn False
# 280 block6b_expand_activation False
# 281 block6b_dwconv False
# 282 block6b_bn False
# 283 block6b_activation False
# 284 block6b_se_squeeze False
# 285 block6b_se_reshape False
# 286 block6b_se_reduce False
# 287 block6b_se_expand False
# 288 block6b_se_excite False
# 289 block6b_project_conv False
# 290 block6b_project_bn False
# 291 block6b_drop False
# 292 block6b_add False
# 293 block6c_expand_conv False
# 294 block6c_expand_bn False
# 295 block6c_expand_activation False
# 296 block6c_dwconv False
# 297 block6c_bn False
# 298 block6c_activation False
# 299 block6c_se_squeeze False
# 300 block6c_se_reshape False
# 301 block6c_se_reduce False
# 302 block6c_se_expand False
# 303 block6c_se_excite False
# 304 block6c_project_conv False
# 305 block6c_project_bn False
# 306 block6c_drop False
# 307 block6c_add False
# 308 block6d_expand_conv False
# 309 block6d_expand_bn False
# 310 block6d_expand_activation False
# 311 block6d_dwconv False
# 312 block6d_bn False
# 313 block6d_activation False
# 314 block6d_se_squeeze False
# 315 block6d_se_reshape False
# 316 block6d_se_reduce False
# 317 block6d_se_expand False
# 318 block6d_se_excite False
# 319 block6d_project_conv False
# 320 block6d_project_bn False
# 321 block6d_drop False
# 322 block6d_add False
# 323 block6e_expand_conv False
# 324 block6e_expand_bn False
# 325 block6e_expand_activation False
# 326 block6e_dwconv False
# 327 block6e_bn False
# 328 block6e_activation False
# 329 block6e_se_squeeze False
# 330 block6e_se_reshape False
# 331 block6e_se_reduce False
# 332 block6e_se_expand False
# 333 block6e_se_excite False
# 334 block6e_project_conv False
# 335 block6e_project_bn False
# 336 block6e_drop False
# 337 block6e_add False
# 338 block6f_expand_conv False
# 339 block6f_expand_bn False
# 340 block6f_expand_activation False
# 341 block6f_dwconv False
# 342 block6f_bn False
# 343 block6f_activation False
# 344 block6f_se_squeeze False
# 345 block6f_se_reshape False
# 346 block6f_se_reduce False
# 347 block6f_se_expand False
# 348 block6f_se_excite False
# 349 block6f_project_conv False
# 350 block6f_project_bn False
# 351 block6f_drop False
# 352 block6f_add False
# 353 block7a_expand_conv False
# 354 block7a_expand_bn False
# 355 block7a_expand_activation False
# 356 block7a_dwconv False
# 357 block7a_bn False
# 358 block7a_activation False
# 359 block7a_se_squeeze False
# 360 block7a_se_reshape False
# 361 block7a_se_reduce False
# 362 block7a_se_expand False
# 363 block7a_se_excite False
# 364 block7a_project_conv False
# 365 block7a_project_bn False
# 366 block7b_expand_conv False
# 367 block7b_expand_bn False
# 368 block7b_expand_activation False
# 369 block7b_dwconv False
# 370 block7b_bn True
# 371 block7b_activation True
# 372 block7b_se_squeeze True
# 373 block7b_se_reshape True
# 374 block7b_se_reduce True
# 375 block7b_se_expand True
# 376 block7b_se_excite True
# 377 block7b_project_conv True
# 378 block7b_project_bn True
# 379 block7b_drop True
# 380 block7b_add True
# 381 top_conv True
# 382 top_bn True
# 383 top_activation True

# %%
# Now we've unfrozen some of the layers closer to the top, how many trainable variables are there?
print(len(model.trainable_variables))
# Out:
# 14

# %%
# Set EarlyStopping callback to stop training if model's val_loss doesn't improve for 3 epochs
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = "val_loss",  # watch the val loss metric
                                                  patience = 3)          # if val loss decreases for 3 epochs in a row, stop training

# %%
# Creating learning rate reduction callback
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss",
                                                 factor=0.2,         # multiply the learning rate by 0.2 (reduce by 5x)
                                                 patgience=2,
                                                 verbose=1,          # print out when learning rate goes down
                                                 min_lr=1e-7)

# %%
# Refit the model (same as model expect with more trainable layers)
fine_tune_epochs = 20 # model has already done 5 epochs (feature extraction), this is the total number of epochs we're after (10 + 10 = 20)

history_fine_tune = model.fit(train_data,
                              epochs=fine_tune_epochs,
                              steps_per_epoch=len(train_data),
                              validation_data=valid_data,
                              validation_steps=len(valid_data),
                              initial_epoch=history.epoch[-1],  # start training from previous last epoch
                              callbacks=[early_stopping, # stop model after X epochs of no improvements
                                         reduce_lr]) # reduce the learning rate after X epochs of no improvements
# Out:
# Epoch 10/20
# 131/131 [==============================] - 308s 2s/step - loss: 0.0760 - accuracy: 0.9756 - val_loss: 0.3018 - val_accuracy: 0.9038 - lr: 1.0000e-04
# Epoch 11/20
# 131/131 [==============================] - 288s 2s/step - loss: 0.0588 - accuracy: 0.9796 - val_loss: 0.2016 - val_accuracy: 0.9404 - lr: 1.0000e-04
# Epoch 12/20
# 131/131 [==============================] - 285s 2s/step - loss: 0.0540 - accuracy: 0.9818 - val_loss: 0.1943 - val_accuracy: 0.9308 - lr: 1.0000e-04
# Epoch 13/20
# 131/131 [==============================] - 285s 2s/step - loss: 0.0380 - accuracy: 0.9871 - val_loss: 0.3471 - val_accuracy: 0.9019 - lr: 1.0000e-04
# Epoch 14/20
# 131/131 [==============================] - 288s 2s/step - loss: 0.0366 - accuracy: 0.9868 - val_loss: 0.1962 - val_accuracy: 0.9404 - lr: 1.0000e-04
# Epoch 15/20
# 131/131 [==============================] - 285s 2s/step - loss: 0.0298 - accuracy: 0.9897 - val_loss: 0.1193 - val_accuracy: 0.9577 - lr: 1.0000e-04
# Epoch 16/20
# 131/131 [==============================] - 291s 2s/step - loss: 0.0287 - accuracy: 0.9897 - val_loss: 0.1565 - val_accuracy: 0.9481 - lr: 1.0000e-04
# Epoch 17/20
# 131/131 [==============================] - 282s 2s/step - loss: 0.0239 - accuracy: 0.9907 - val_loss: 0.1930 - val_accuracy: 0.9346 - lr: 1.0000e-04
# Epoch 18/20
# 131/131 [==============================] - 282s 2s/step - loss: 0.0224 - accuracy: 0.9919 - val_loss: 0.1148 - val_accuracy: 0.9654 - lr: 1.0000e-04
# Epoch 19/20
# 131/131 [==============================] - 284s 2s/step - loss: 0.0264 - accuracy: 0.9911 - val_loss: 0.1487 - val_accuracy: 0.9519 - lr: 1.0000e-04
# Epoch 20/20
# 131/131 [==============================] - 285s 2s/step - loss: 0.0166 - accuracy: 0.9947 - val_loss: 0.1294 - val_accuracy: 0.9615 - lr: 1.0000e-04

# %%
# Evaluate the model
test_loss,test_acc = model.evaluate(test_data,verbose=1)
print("\n\ntest accuarcy: ",test_acc)
# Out:
# 526/526 [==============================] - 37s 70ms/step - loss: 0.1392 - accuracy: 0.9525
#
#
# test accuarcy:  0.9524714946746826

# %%
# Check out our model's training curves
plot_loss_curves(history_fine_tune)

# %%
# Let's create a function to compare training histories
def compare_historys(original_history, new_history, initial_epochs=5):
  """
  Comapres two TensorFlow History objects.
  """
  # Get origional history measurements
  acc = original_history.history['accuracy']
  loss = original_history.history['loss']

  val_acc = original_history.history['val_accuracy']
  val_loss = original_history.history['val_loss']

  # Combine origional history metrics with new_history metrics
  total_acc = acc + new_history.history['accuracy']
  total_loss = loss + new_history.history['loss']

  total_val_acc = val_acc + new_history.history['val_accuracy']
  total_val_loss = val_loss + new_history.history['val_loss']

  # Make plot for accuracy
  plt.figure(figsize=(8,8))
  plt.subplot(2,1,1)
  plt.plot(total_acc, label="Training Accuracy", c='r', marker='o', linestyle='dashed')
  plt.plot(total_val_acc, label="Val Accuracy", c='b', marker='*', linestyle='dashed')
  plt.plot([initial_epochs-1, initial_epochs-1], plt.ylim(), label="Start Fine Tuning", c='g', linestyle='dashed')
  plt.legend(loc="lower right")
  plt.title("Training and Validation Accuracy")

  # Make plot for loss
  plt.figure(figsize=(8,8))
  plt.subplot(2,1,2)
  plt.plot(total_loss, label="Training Loss", c='r', marker='o', linestyle='dashed')
  plt.plot(total_val_loss, label="Val Loss", c='g', marker='*', linestyle='dashed')
  plt.plot([initial_epochs-1, initial_epochs-1], plt.ylim(), label="Start Fine Tuning", c='b', linestyle='dashed')
  plt.legend(loc="upper right")
  plt.title("Training and Validation Loss")

# %%
# Compare the histories of feature extraction model with fine-tuning model
compare_historys(original_history=history,
                 new_history=history_fine_tune,
                 initial_epochs=5)

# %% [markdown]
# **Making predictions with our trained model**

# %%
# Make predictions with model
preds_probs = model.predict(test_data, verbose=1) # set verbosity to see how long is left
# Out:
# 526/526 [==============================] - 36s 63ms/step

# %%
len(test_data)
# Out:
# 526

# %%
# How many predictions are there?
len(preds_probs)
# Out:
# 526

# %%
# What's the shape of our predictions?
preds_probs.shape
# Out:
# (526, 5)

# %%
# Let's see what the first 10 predictions look like
preds_probs[:5]
# Out:
# array([[7.4638203e-03, 9.9223161e-01, 3.0452001e-04, 6.3408606e-10,
#         6.7585459e-10],
#        [7.8074708e-10, 4.0077514e-13, 4.3179720e-11, 2.5877374e-09,
#         1.0000000e+00],
#        [8.0514289e-02, 8.8292472e-06, 9.1946393e-01, 1.2977707e-05,
#         4.1245407e-08],
#        [6.0490072e-07, 5.1172861e-11, 5.0380902e-05, 9.9928373e-12,
#         9.9994898e-01],
#        [7.6530654e-08, 9.9999034e-01, 4.3268142e-07, 9.0580252e-06,
#         1.5001152e-08]], dtype=float32)

# %%
# What does the first prediction probability array look like?
preds_probs[0], len(preds_probs[0]), sum(preds_probs[0])
# Out:
# (array([7.4638203e-03, 9.9223161e-01, 3.0452001e-04, 6.3408606e-10,
#         6.7585459e-10], dtype=float32), 5, 0.9999999490394612)

# %%
# We get one prediction probability per class (in our case there's 101 prediction probabilities)
print(f"Number of prediction probabilities for sample 0: {len(preds_probs[0])}")
print(f"What prediction probability sample 0 looks like:\n {preds_probs[0]}")
print(f"The class with the highest predicted probability by the model for sample 0: {preds_probs[0].argmax()}")
# Out:
# Number of prediction probabilities for sample 0: 5
# What prediction probability sample 0 looks like:
#  [7.4638203e-03 9.9223161e-01 3.0452001e-04 6.3408606e-10 6.7585459e-10]
# The class with the highest predicted probability by the model for sample 0: 1

# %%
test_data.class_names[0]
# Out:
# 'Anethum graveolens'

# %%
# Get the pred classes of each label
pred_classes = preds_probs.argmax(axis=1)

# How do they look?
pred_classes[:10]
# Out:
# array([1, 4, 2, 4, 1, 1, 3, 1, 3, 0])

# %%
# How many pred classes do we have?
len(pred_classes)
# Out:
# 526

# %%
# To get our test labels we need to unravel our test_data BatchDataset (Unbatch dataset)
y_labels = []
for images, labels in test_data.unbatch():
  y_labels.append(labels.numpy().argmax()) # currently test labels look like: [0, 0, 0, 1, .... 0, 0], we want the index value where the "1" occurs

# %%
# Look at the first 10
y_labels[:10]
# Out:
# [0, 1, 4, 1, 3, 2, 3, 1, 0, 3]

# %%
# How many y_labels are there?
len(y_labels)
# Out:
# 526

# %%
# Let's try scikit-learn's accuracy score function and see what it comes up with
from sklearn.metrics import accuracy_score
sklearn_accuracy = accuracy_score(y_true=y_labels,
                                  y_pred=pred_classes)
sklearn_accuracy
# Out:
# 0.2623574144486692

# %% [markdown]
# ##Let's get visual: making a confusion matrix

# %%
# Get a list of class names
class_names = test_data.class_names
class_names
# Out:
# ['Anethum graveolens',
#  'Carum carvi',
#  'Cyminum cuminum',
#  'Foeniculum vulgare',
#  'Mixed Image']

# %%
import itertools
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix

# We need to make some changes to our make_confusion_matrix function to ensure the x-labels print vertically
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15, norm=False, savefig=False): 
  """Makes a labelled confusion matrix comparing predictions and ground truth labels.

  If classes is passed, confusion matrix will be labelled, if not, integer class values
  will be used.

  Args:
    y_true: Array of truth labels (must be same shape as y_pred).
    y_pred: Array of predicted labels (must be same shape as y_true).
    classes: Array of class labels (e.g. string form). If `None`, integer labels are used.
    figsize: Size of output figure (default=(10, 10)).
    text_size: Size of output figure text (default=15).
    norm: normalize values or not (default=False).
    savefig: save confusion matrix to file (default=False).
  
  Returns:
    A labelled confusion matrix plot comparing y_true and y_pred.

  Example usage:
    make_confusion_matrix(y_true=test_labels, # ground truth test labels
                          y_pred=y_preds, # predicted labels
                          classes=class_names, # array of class label names
                          figsize=(15, 15),
                          text_size=10)
  """  
  # Create the confustion matrix
  cm = confusion_matrix(y_true, y_pred)
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
  n_classes = cm.shape[0] # find the number of classes we're dealing with

  # Plot the figure and make it pretty
  fig, ax = plt.subplots(figsize=figsize)
  cax = ax.matshow(cm, cmap=plt.cm.Blues) # colors will represent how 'correct' a class is, darker == better
  fig.colorbar(cax)

  # Are there a list of classes?
  if classes:
    labels = classes
  else:
    labels = np.arange(cm.shape[0])
  
  # Label the axes
  ax.set(title="Confusion Matrix",
         xlabel="Predicted label",
         ylabel="True label",
         xticks=np.arange(n_classes), # create enough axis slots for each class
         yticks=np.arange(n_classes), 
         xticklabels=labels, # axes will labeled with class names (if they exist) or ints
         yticklabels=labels)
  
  # Make x-axis labels appear on bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  ### Changed (plot x-labels vertically) ###
  plt.xticks(rotation=70, fontsize=text_size)
  plt.yticks(fontsize=text_size)

  # Set the threshold for different colors
  threshold = (cm.max() + cm.min()) / 2.

  # Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    if norm:
      plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)
    else:
      plt.text(j, i, f"{cm[i, j]}",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)

  # Save the figure to the current working directory
  if savefig:
    fig.savefig("confusion_matrix.png")

# %%
make_confusion_matrix(y_true=y_labels,
                      y_pred=pred_classes,
                      classes=class_names,
                      figsize=(10, 10),
                      text_size=10,
                      savefig=True)

# %% [markdown]
# ##Let's keep the evaluation train going, time for a classification report
# Scikit-learn has a helpful function for acquiring many different classification metrics per class (e.g. precision, recall and F1) called classification_report, let's try it out.

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true=y_labels,
                            y_pred=pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.23      0.26      0.24       103
#            1       0.26      0.25      0.26       108
#            2       0.24      0.22      0.23       103
#            3       0.25      0.25      0.25       107
#            4       0.34      0.32      0.33       105
#
#     accuracy                           0.26       526
#    macro avg       0.26      0.26      0.26       526
# weighted avg       0.26      0.26      0.26       526

# %%
# Get a dictionary of the classification report
classification_report_dict = classification_report(y_labels, pred_classes, output_dict=True)
classification_report_dict
# Out:
# {'0': {'f1-score': 0.242152466367713,
#   'precision': 0.225,
#   'recall': 0.2621359223300971,
#   'support': 103},
#  '1': {'f1-score': 0.2571428571428572,
#   'precision': 0.2647058823529412,
#   'recall': 0.25,
#   'support': 108},
#  '2': {'f1-score': 0.23232323232323235,
#   'precision': 0.24210526315789474,
#   'recall': 0.22330097087378642,
#   'support': 103},
#  '3': {'f1-score': 0.25,
#   'precision': 0.24770642201834864,
#   'recall': 0.2523364485981308,
#   'support': 107},
#  '4': {'f1-score': 0.33170731707317075,
#   'precision': 0.34,
#   'recall': 0.3238095238095238,
#   'support': 105},
#  'accuracy': 0.2623574144486692,
#  'macro avg': {'f1-score': 0.26266517458139466,
#   'precision': 0.2639035135058369,
#   'recall': 0.2623165731223076,
#   'support': 526},
#  'weighted avg': {'f1-score': 0.2627788856069941,
#   'precision': 0.26407730904057813,
#   'recall': 0.2623574144486692,
#   'support': 526}}

# %%
class_names[4]
# Out:
# 'Mixed Image'

# %%
classification_report_dict["4"]
# Out:
# {'f1-score': 0.33170731707317075,
#  'precision': 0.34,
#  'recall': 0.3238095238095238,
#  'support': 105}

# %%
classification_report_dict["4"]["f1-score"]
# Out:
# 0.33170731707317075

# %%
# Create empty dictionary
class_f1_scores = {}
# Loop through classification report dictionary items
for k, v in classification_report_dict.items():
  if k == "accuracy": # stop once we get to accuracy key
    break
  else:
    # Add class names and f1-scores to new dictionary
    class_f1_scores[class_names[int(k)]] = v["f1-score"]
class_f1_scores
# Out:
# {'Anethum graveolens': 0.242152466367713,
#  'Carum carvi': 0.2571428571428572,
#  'Cyminum cuminum': 0.23232323232323235,
#  'Foeniculum vulgare': 0.25,
#  'Mixed Image': 0.33170731707317075}

# %%
# Trun f1-scores into dataframe for visualization
import pandas as pd
f1_scores = pd.DataFrame({"class_names": list(class_f1_scores.keys()),
                          "f1-score": list(class_f1_scores.values())}).sort_values("f1-score", ascending=False)

# %%
# What does our dataframe look like?
f1_scores[:10]
# Out:
#           class_names  f1-score
# 4         Mixed Image  0.331707
# 1         Carum carvi  0.257143
# 3  Foeniculum vulgare  0.250000
# 0  Anethum graveolens  0.242152
# 2     Cyminum cuminum  0.232323

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12,10))
scores = ax.barh(range(len(f1_scores)), f1_scores['f1-score'].values)
ax.set_yticks(range(len(f1_scores)))
ax.set_yticklabels(f1_scores["class_names"])
ax.set_xlabel("F1-score")
ax.set_title("F1-scores for 101 Different Food Classes (predicted by Food Vision mini)")
ax.invert_yaxis(); # reverse the order of our plot



# Challenge: add values to the end of each bar of what the actual f1-score is 
# (hint: use the "autolabel" function from here: https://matplotlib.org/2.0.2/examples/api/barchart_demo.html)

# %% [markdown]
# ##Visualizing predictions on test images

# %%
# Create a function to load and prepare images
def load_and_prep_image(filename, img_shape=300, scale=True):
  """
  Reads in an image from filename, turns it into a tensor and reshapes into
  specified shape (img_shape, img_shape, color_channels=3).

  Args:
    filename (str): path to target image
    image_shape (int): height/width dimension of target image size
    scale (bool): scale piexel values from 0-255 to 0-1 or not

  Returns:
    Image tensor of shape (img_shape, img_shape, 3)
  """
  
  # Read in the image
  img = tf.io.read_file(filename)

  # Decode image into tensor
  img = tf.io.decode_image(img, channels=3)

  # Resize the image
  img = tf.image.resize(img, [img_shape, img_shape])
  
  # Scale? Yes/No
  if scale:
    # Rescale the image (get all values between 0 and 1)
    return img/255.
  else:
    return img # Don't need to rescale images for EfficientNet models in TensorFlow

# %%
# Make preds on a series of random images
import os
import random

plt.figure(figsize=(20,10))

for i in range(4):
  
  # Choose a random image from a random class
  class_name = random.choice(class_names)
  filename = random.choice(os.listdir(test_dir + "/" + class_name))
  filepath = test_dir + "/" + class_name + "/" + filename

  # Load the image and make predictions
  img = load_and_prep_image(filepath, scale=False)
  img_expanded = tf.expand_dims(img, axis=0)
  # print(img_expanded.shape)
  pred_prob = model.predict(img_expanded)       # get prediction probabilities array
  pred_class = class_names[pred_prob.argmax()]  # get highest prediction probability index and match it class_names list
  # print(pred_prob)
  # print(pred_class)

  # Plot the images
  plt.subplot(2, 2, i+1)
  # print(img)
  plt.imshow(img/255.)
  
  if class_name == pred_class:
    title_color = "g"  # if predicted class matches truth class, make text green
  else:
    title_color = "r"

  plt.title(f"Actual: {class_name}, pred: {pred_class}, prob: {pred_prob.max():.2f}", c=title_color)
  plt.axis(False)

# %%
def get_file_size(file_path):
    size = os.path.getsize(file_path)
    return size

# %%
def convert_bytes(size, unit=None):
    if unit == "KB":
        return print('File size: ' + str(round(size / 1024, 3)) + ' Kilobytes')
    elif unit == "MB":
        return print('File size: ' + str(round(size / (1024 * 1024), 3)) + ' Megabytes')
    else:
        return print('File size: ' + str(size) + ' bytes')

# %%
#Define a variable to store our model
MODEL_NAME = "fennal_model_new.h5"

# %%
model.save(MODEL_NAME)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
convert_bytes(get_file_size(MODEL_NAME), "MB")
# Out:
# File size: 56.549 Megabytes

# %% [markdown]
# #TF LITE MODEL

# %%
# Convert the model
from tensorflow import lite
tf_lite_converter = tf.lite.TFLiteConverter.from_keras_model(model) # path to the SavedModel directory
tf_lite_converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = tf_lite_converter.convert()
# Out:
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded

# %%
TF_LITE_MODEL_FILE_NAME = "tf_lite_fennal_01.tflite"

# %%
# Save the model
tflite_model_name = TF_LITE_MODEL_FILE_NAME
open(tflite_model_name, "wb").write(tflite_model)
# Out:
# 12298768

# %%
convert_bytes(get_file_size(tflite_model_name), "MB")
# Out:
# File size: 11.729 Megabytes

# %%
# Are any of the layers in our model frozen?
for layer in model.layers:
  layer.trainable = True
  print(layer.name, layer.trainable, layer.dtype, layer.dtype_policy)
# Out:
# input_layer True float32 <Policy "float32">
# sequential True float32 <Policy "float32">
# efficientnetb0 True float32 <Policy "float32">
# global_average_pooling_layer True float32 <Policy "float32">
# output_layers True float32 <Policy "float32">

# %%
# Creating learning rate reduction callback
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss",
                                                 factor=0.2,         # multiply the learning rate by 0.2 (reduce by 5x)
                                                 patgience=2,
                                                 verbose=1,          # print out when learning rate goes down
                                                 min_lr=1e-7)

# %%
# Compile the model
model.compile(loss="categorical_crossentropy",
                     optimizer=tf.keras.optimizers.Adam(0.0001),
                     metrics=["accuracy"])

# %%
# Fit the model
history_1 = model.fit(train_data,
                    epochs=10,
                    steps_per_epoch=len(train_data),
                    validation_data=test_data,
                    validation_steps= len(test_data),
                    callbacks=[early_stoppage, reduce_lr])
# Out:
# Epoch 1/10
# 1028/1028 [==============================] - 219s 200ms/step - loss: 4.7171e-04 - accuracy: 1.0000 - val_loss: 5.8556e-07 - val_accuracy: 1.0000
# Epoch 2/10
# 1028/1028 [==============================] - 159s 154ms/step - loss: 2.5362e-06 - accuracy: 1.0000 - val_loss: 1.5337e-08 - val_accuracy: 1.0000
# Epoch 3/10
# 1028/1028 [==============================] - 149s 145ms/step - loss: 3.5435e-07 - accuracy: 1.0000 - val_loss: 7.6684e-09 - val_accuracy: 1.0000
# Epoch 4/10
# 1028/1028 [==============================] - 140s 136ms/step - loss: 4.4529e-08 - accuracy: 1.0000 - val_loss: 7.3199e-09 - val_accuracy: 1.0000
# Epoch 5/10
# 1028/1028 [==============================] - 137s 133ms/step - loss: 4.6037e-08 - accuracy: 1.0000 - val_loss: 9.0627e-09 - val_accuracy: 1.0000

# %%
# Check out our model's training curves
plot_loss_curves(history_1)

# %%
def get_file_size(file_path):
    size = os.path.getsize(file_path)
    return size

# %%
def convert_bytes(size, unit=None):
    if unit == "KB":
        return print('File size: ' + str(round(size / 1024, 3)) + ' Kilobytes')
    elif unit == "MB":
        return print('File size: ' + str(round(size / (1024 * 1024), 3)) + ' Megabytes')
    else:
        return print('File size: ' + str(size) + ' bytes')

# %%
#Define a variable to store our model
MODEL_NAME = "eficientnetb0_black_pepper_finetune.h5"

# %%
model.save(MODEL_NAME)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
convert_bytes(get_file_size(MODEL_NAME), "MB")
# Out:
# File size: 46.934 Megabytes

# %% [markdown]
# ## TF LITE MODEL

# %%
TF_LITE_MODEL_FILE_NAME = "tf_lite_model.tflite"

# %%
# Convert the model
from tensorflow import lite
tf_lite_converter = tf.lite.TFLiteConverter.from_keras_model(model) # path to the SavedModel directory
tf_lite_converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = tf_lite_converter.convert()
# Out:
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# INFO:tensorflow:Assets written to: /tmp/tmpd2gmvj3i/assets
# INFO:tensorflow:Assets written to: /tmp/tmpd2gmvj3i/assets
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.

# %%
TF_LITE_MODEL_FILE_NAME = "tf_lite_model_add_efficientnet_B3.tflite"

# %%
# Save the model
tflite_model_name = TF_LITE_MODEL_FILE_NAME
open(tflite_model_name, "wb").write(tflite_model)
# Out:
# 12491408
